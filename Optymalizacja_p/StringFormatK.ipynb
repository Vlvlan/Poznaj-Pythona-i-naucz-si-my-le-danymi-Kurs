# %% [markdown]
# <a href="https://colab.research.google.com/github/Vlvlan/Poznaj-Pythona-i-naucz-si-my-le-danymi-Kurs/blob/main/StringFormatK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lista = [0,1,2,3,4]

print(*lista, sep="----")
# Out:
# 0----1----2----3----4

# %%
print("Hello", "Jestem", "Paweł", sep="-----")
# Out:
# Hello-----Jestem-----Paweł

# %%
print("Hello" + "Jestem" + "Paweł")
# Out:
# HelloJestemPaweł

# %%
for i in lista:
  print(i, end=" : ")
# Out:
# 0 : 1 : 2 : 3 : 4 :

# %%
print("Linia 1\nLinia 2")
# Out:
# Linia 1
# Linia 2

# %%
print("Linia 1\n\tLinia 2")
# Out:
# Linia 1
# 	Linia 2

# %%
print("\'hello \'")
# Out:
# 'hello '

# %%
print("C:\\folder")
# Out:
# C:\folder

# %%
print("C:\\folder\\")
# Out:
# C:\folder\

# %%
imie = "Asia"
wiek = 20
print(f"mam na imię {imie}, i mam {wiek} lat")
# Out:
# mam na imię Asia, i mam 20 lat

# %%
print("mam na imię {0}, i mam {1} lat, mój brak też ma {1} lat".format(imie, wiek))
# Out:
# mam na imię Asia, i mam 20 lat, mój brak też ma 20 lat

# %%
x = 2.2154215125
print(f"X wynosi: {x:.2f}")
# Out:
# X wynosi: 2.22

# %%
t = 10000000
print(f"{t:,}")
# Out:
# 10,000,000

# %%
r = 0.80
print(f"{r:.0%}")
# Out:
# 80%

# %%
l = 40
print(f"[{l:>10}]")
# Out:
# [        40]

# %%
s = """ linia 1
linia 2
linia 3"""
print(s)

# %%
def pole(a,b):
  """ Liczy pole prostokąta, ma dwa parametry"""
  return a * b
print(pole(1,3))
# Out:
# 3

# %%
print(help(pole))
# Out:
# Help on function pole in module __main__:
#
# pole(a, b)
#     Liczy pole prostokąta, ma dwa parametry
#
# None

# %%
print("badzoooooooooooooooooooooooooooooooooooooooooooooooooooooooooo",
      "oooooooo długi tekst", sep="")

# %%
tekst = "python jest najlepszy"

print(tekst.upper())

# %%
print(tekst.lower())

# %%
print(tekst.capitalize())

# %%
print(tekst.title())

# %%
print(tekst.replace("asdsfa", "najgorszy"))

# %%
t = tekst.split(sep=" ")

# %%
print("-".join(t))

# %%
print(tekst.count(""))

# %%
print(tekst.find("x"))

# %%
print(len(tekst))

# %%
print(tekst.startswith("jest"))

# %%
print(tekst.endswith("y"))

# %%
print(tekst.isdigit())

# %%
tekst = "         python jest         najlepszy            "

# %%
print(tekst.strip())

# %%
print(tekst.lstrip())

# %%
print(tekst.rstrip())

# %%
nowy_tekst = " ".join(tekst.split())
print(nowy_tekst)
