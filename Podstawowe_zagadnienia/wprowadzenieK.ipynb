# %%
5 + 5
# Out:
# 10

# %%
5 - 3
# Out:
# 2

# %%
6 / 3
# Out:
# 2.0

# %%
6 / 4
# Out:
# 1.5

# %%
4 * 5
# Out:
# 20

# %%
6 // 4
# Out:
# 1

# %%
6 ** 2
# Out:
# 36

# %%
6 % 4
# Out:
# 2

# %%
(2 + 3) * 5 **2
# Out:
# 125

# %% [markdown]
# Nazewnictwo zmiennych

# %%
wynik = (2 + 3) * 5 ** 2
print(wynik)
# Out:
# 125

# %%
w2ynik2 = 4

# %%
wynik_3 = 3
imie_nazwisko = 2 # odzielanie słów _ nazywamy notacją snake case

# %%
WYNIK = 20
wynik = 40
Wynik = 60
print(WYNIK, wynik, Wynik)
# dla interpretera pythona małe litery i ich duże odpowiedniki to zupełnie inne znaki
# Out:
# 20 40 60

# %%
test = 15
print(test)
test = 30
print(test)
# Out:
# 15
# 30

# %%
ąę = 40
# używanie polskich znaków jest akceptowane ale powinniśmy tego unikać
print()
# Out:
# 40

# %%
# hello world

# %% [markdown]
# Typy Danych

# %%
print(type(20))
# funkcja type() zwraca nam typ wprowadzonego obiektu
# Out:
# <class 'int'>

# %%
print(type(20.0))
# Out:
# <class 'float'>

# %%
znak = "Polska górą"
print(znak)
# Out:
# Polska górą

# %%
print(type(znak))
# Out:
# <class 'str'>

# %%
bool_1  = True
bool_2 = False
print(bool_1, bool_2)
# Out:
# True False

# %%
print(type(bool_1))
# Out:
# <class 'bool'>

# %%
print(int(20.5))
# Out:
# 20

# %%
print(float(20))
# Out:
# 20.0

# %%
przyklad = "20"
print(int(przyklad))
# Out:
# 20

# %%
print(type(str(20)))
# Out:
# <class 'str'>

# %%
print(bool(0))
# Out:
# True

# %%
z = " "
print(bool(z))
# Out:
# True
