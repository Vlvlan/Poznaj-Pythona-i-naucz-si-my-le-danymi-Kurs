# %% [markdown]
# <a href="https://colab.research.google.com/github/Vlvlan/Poznaj-Pythona-i-naucz-si-my-le-danymi-Kurs/blob/main/krotkiK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
krotka = ("String", 21, 2.5, True, False, None)
print(krotka)
# Out:
# ('String', 21, 2.5, True, False, None)

# %%
print(krotka[-1])
# Out:
# None

# %%
krotka.count("hello")
# Out:
# 0

# %%
krotka.index(True)
# Out:
# 3

# %%
uczen = ("Ala", "15", "7B")

imie, wiek, klasa = uczen

print(f"{imie} ma {wiek} lat i jest w klasie {klasa}")
# Out:
# Ala ma 15 lat i jest w klasie 7B

# %%
wynik = (100, 90, 80, 77, 50, 45, 31, 20, 11)

najlepszy, *reszta, najgorszy = wynik
print(f"Najlepszy wynik: {najlepszy}, reszta: {reszta}, najgorszy wynik: {najgorszy}")
# Out:
# Najlepszy wynik: 100, reszta: [90, 80, 77, 50, 45, 31, 20], najgorszy wynik: 11

# %%
a = 10
b = 20
print(a,b)
a,b = b,a
print(a,b)
# Out:
# 10 20
# 20 10
